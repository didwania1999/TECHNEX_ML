# %% [markdown]
# #Dictionaries

# %%
import numpy as np

# %%
d={}
print(type(d))
# Out:
# <class 'dict'>

# %%
d1={"Name":["chandan","amit","aman"],"Age":[29,30,31]}

# %%
d1.keys()
# Out:
# dict_keys(['Name', 'Age'])

# %%
d1.values()
# Out:
# dict_values([['chandan', 'amit', 'aman'], [29, 30, 31]])

# %%
d1.items()
# Out:
# dict_items([('Name', ['chandan', 'amit', 'aman']), ('Age', [29, 30, 31])])

# %%
d1["Name"]
# Out:
# ['chandan', 'amit', 'aman']

# %%
import pandas as pd

# %%
a=[11,12,13]
s=pd.Series(a)#series

# %%
print(type(a))
print(type(s))
# Out:
# <class 'list'>
# <class 'pandas.core.series.Series'>

# %%
a
# Out:
# [11, 12, 13]

# %%
s
# Out:
# 0    11
# 1    12
# 2    13
# dtype: int64

# %%
s.shape
# Out:
# (3,)

# %%
s.ndim
# Out:
# 1

# %%
s.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
s.values
# Out:
# array([11, 12, 13], dtype=int64)

# %%
#typcasting#series is list with index

# %%
#customising index
s=pd.Series(a,index=["a","b","c"])
s
#size of integer is 64 but in numpy is 32
# Out:
# a    11
# b    12
# c    13
# dtype: int64

# %%
d2={"Name":["chandan","amit"],"Age":[29,20]}
df=pd.DataFrame(d2)

# %%
print(type(d2))
print(type(df))
# Out:
# <class 'dict'>
# <class 'pandas.core.frame.DataFrame'>

# %%
d2
# Out:
# {'Name': ['chandan', 'amit'], 'Age': [29, 20]}

# %%
df
# Out:
#       Name  Age
# 0  chandan   29
# 1     amit   20

# %%
df.ndim
# Out:
# 2

# %%
df.keys
# Out:
# <bound method NDFrame.keys of       Name  Age
# 0  chandan   29
# 1     amit   20>

# %%
df.index
# Out:
# RangeIndex(start=0, stop=2, step=1)

# %%
len(df)
# Out:
# 2

# %%
df.columns
# Out:
# Index(['Name', 'Age'], dtype='object')

# %%
df["Name"]
# Out:
# 0    chandan
# 1       amit
# Name: Name, dtype: object

# %%
df.Age
# Out:
# 0    29
# 1    20
# Name: Age, dtype: int64

# %%
mydata=pd.read_excel(r"C:\Users\HP\Desktop\TECHNEX DATA\DataSets-master\Population_Summary.xlsx")#r easily converts into best form of URI

# %%
print(type(mydata))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
mydata.head(1)
# Out:
#   Rank       State_UT  Population  Rulal  Urban  Share  Growth Country  \
# 0    1  Uttar Pradesh   199812341  77.73  22.27   16.5   20.23  Brazil
#
#    World_Rank
# 0           5

# %%
mydata.tail(1)
# Out:
#    Rank     State_UT  Population  Rulal  Urban  Share  Growth  Country  \
# 34  UT6  Lakshadweep       64473  21.93  78.07   0.01     6.3  Bermuda
#
#     World_Rank
# 34         205

# %%
mydata.keys()
# Out:
# Index(['Rank', 'State_UT', 'Population', 'Rulal', 'Urban', 'Share', 'Growth',
#        'Country', 'World_Rank'],
#       dtype='object')

# %%
mydata.columns
# Out:
# Index(['Rank', 'State_UT', 'Population', 'Rulal', 'Urban', 'Share', 'Growth',
#        'Country', 'World_Rank'],
#       dtype='object')

# %%
mydata["Population"].sum(axis=0)#total population
# Out:
# 1210854977

# %%
p=mydata["Population"]
#print(p)
print(type(p))
# Out:
# <class 'pandas.core.series.Series'>

# %%
ps=mydata[["Population","State_UT"]]

# %%
ps
# Out:
#     Population           State_UT
# 0    199812341      Uttar Pradesh
# 1    112374333        Maharashtra
# 2    104099452              Bihar
# 3     91276115        West Bengal
# 4     84580777     Andhra Pradesh
# 5     72626809     Madhya Pradesh
# 6     72147030         Tamil Nadu
# 7     68548437          Rajasthan
# 8     61095297          Karnataka
# 9     60439692            Gujarat
# 10    41974218             Odisha
# 11    33406061             Kerala
# 12    32988134          Jharkhand
# 13    31205576              Assam
# 14    27743338             Punjab
# 15    25545198       Chhattisgarh
# 16    25351462            Haryana
# 17    16787941              Delhi
# 18    12541302    Jammu & Kashmir
# 19    10086292        Uttarakhand
# 20     6864602   Himachal Pradesh
# 21     3673917            Tripura
# 22     2966889          Meghalaya
# 23     2855794            Manipur
# 24     1978502           Nagaland
# 25     1458545                Goa
# ...

# %%
#iloc

# %%
mydata.iloc[0,:]
# Out:
# Rank                      1
# State_UT      Uttar Pradesh
# Population        199812341
# Rulal                 77.73
# Urban                 22.27
# Share                  16.5
# Growth                20.23
# Country              Brazil
# World_Rank                5
# Name: 0, dtype: object

# %%
mydata.iloc[:,2:4]
# Out:
#     Population  Rulal
# 0    199812341  77.73
# 1    112374333  54.78
# 2    104099452  88.71
# 3     91276115  68.13
# 4     84580777  66.64
# 5     72626809  72.37
# 6     72147030  51.60
# 7     68548437  75.13
# 8     61095297  61.33
# 9     60439692  57.40
# 10    41974218  83.31
# 11    33406061  52.30
# 12    32988134  75.95
# 13    31205576  85.90
# 14    27743338  62.52
# 15    25545198  76.76
# 16    25351462  65.12
# 17    16787941   2.50
# 18    12541302  72.62
# 19    10086292  69.77
# 20     6864602  89.97
# 21     3673917  73.83
# 22     2966889  79.93
# 23     2855794  70.79
# 24     1978502  71.14
# 25     1458545  37.83
# 26     1383727  77.06
# 27     1247953  31.67
# 28     1097206  47.89
# 29     1055450   2.75
# 30      610577  74.85
# 31      380581  62.30
# 32      343709  53.28
# 33      243247  24.83
# 34       64473  21.93

# %%
mydata.iloc[5:10,[2,4,5]]
# Out:
#    Population  Urban  Share
# 5    72626809  27.63   6.00
# 6    72147030  48.40   5.96
# 7    68548437  24.87   5.66
# 8    61095297  38.67   5.05
# 9    60439692  42.60   4.99

# %%
mydata.loc[5:10,["Population","Country"]]
# Out:
#     Population    Country
# 5     72626809     Turkey
# 6     72147030     Turkey
# 7     68548437      Congo
# 8     61095297      Italy
# 9     60439692      Italy
# 10    41974218  Argentina

# %%
mydata.iloc[::,2::2]
# Out:
#     Population  Urban  Growth
# 0    199812341  22.27   20.23
# 1    112374333  45.22   15.99
# 2    104099452  11.29   25.42
# 3     91276115  31.87   13.84
# 4     84580777  33.36   10.98
# 5     72626809  27.63   20.35
# 6     72147030  48.40   15.61
# 7     68548437  24.87   21.31
# 8     61095297  38.67   15.60
# 9     60439692  42.60   19.28
# 10    41974218  16.69   14.05
# 11    33406061  47.70    4.91
# 12    32988134  24.05   22.42
# 13    31205576  14.10   17.07
# 14    27743338  37.48   13.89
# 15    25545198  23.24   22.61
# 16    25351462  34.88   19.90
# 17    16787941  97.50   21.21
# 18    12541302  27.38   23.64
# 19    10086292  30.23   18.81
# 20     6864602  10.03   12.94
# 21     3673917  26.17   14.84
# 22     2966889  20.07   27.95
# 23     2855794  29.21   24.50
# 24     1978502  28.86   -0.58
# 25     1458545  62.17    8.23
# 26     1383727  22.94   26.03
# 27     1247953  68.33   28.08
# 28     1097206  52.11   23.48
# 29     1055450  97.25   17.19
# ...

# %%
mydata.drop(["World_Rank"],axis=1,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-171-dde717513ae7> in <module>
# ----> 1 mydata.drop(["World_Rank"],axis=1,inplace=True)
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3938                                            index=index, columns=columns,
#    3939                                            level=level, inplace=inplace,
# -> 3940                                            errors=errors)
#    3941
#    3942     @rewrite_axis_style_signature('mapper', [('copy', True),
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3778         for axis, labels in axes.items():
#    3779             if labels is not None:
# ...

# %%
mydata
# Out:
#    Rank           State_UT  Population  Rulal  Urban  Share  Growth  \
# 0     1      Uttar Pradesh   199812341  77.73  22.27  16.50   20.23
# 1     2        Maharashtra   112374333  54.78  45.22   9.28   15.99
# 2     3              Bihar   104099452  88.71  11.29   8.60   25.42
# 3     4        West Bengal    91276115  68.13  31.87   7.54   13.84
# 4     5     Andhra Pradesh    84580777  66.64  33.36   6.99   10.98
# 5     6     Madhya Pradesh    72626809  72.37  27.63   6.00   20.35
# 6     7         Tamil Nadu    72147030  51.60  48.40   5.96   15.61
# 7     8          Rajasthan    68548437  75.13  24.87   5.66   21.31
# 8     9          Karnataka    61095297  61.33  38.67   5.05   15.60
# 9    10            Gujarat    60439692  57.40  42.60   4.99   19.28
# 10   11             Odisha    41974218  83.31  16.69   3.47   14.05
# 11   12             Kerala    33406061  52.30  47.70   2.76    4.91
# 12   13          Jharkhand    32988134  75.95  24.05   2.72   22.42
# ...

# %%
mydata["Growth"].min()
# Out:
# -0.58

# %%
mydata["Growth"]==mydata["Growth"].min()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24     True
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# 34    False
# Name: Growth, dtype: bool

# %%
mydata[mydata["Growth"]==mydata["Growth"].mean()]
# Out:
# Empty DataFrame
# Columns: [Rank, State_UT, Population, Rulal, Urban, Share, Growth, Country]
# Index: []

# %%
mydata[mydata["Population"]>mydata["Population"].mean()]
# Out:
#    Rank        State_UT  Population  Rulal  Urban  Share  Growth      Country
# 0     1   Uttar Pradesh   199812341  77.73  22.27  16.50   20.23       Brazil
# 1     2     Maharashtra   112374333  54.78  45.22   9.28   15.99       Mexico
# 2     3           Bihar   104099452  88.71  11.29   8.60   25.42  Philippines
# 3     4     West Bengal    91276115  68.13  31.87   7.54   13.84     Viet Nam
# 4     5  Andhra Pradesh    84580777  66.64  33.36   6.99   10.98        Egypt
# 5     6  Madhya Pradesh    72626809  72.37  27.63   6.00   20.35       Turkey
# 6     7      Tamil Nadu    72147030  51.60  48.40   5.96   15.61       Turkey
# 7     8       Rajasthan    68548437  75.13  24.87   5.66   21.31        Congo
# 8     9       Karnataka    61095297  61.33  38.67   5.05   15.60        Italy
# 9    10         Gujarat    60439692  57.40  42.60   4.99   19.28        Italy
# 10   11          Odisha    41974218  83.31  16.69   3.47   14.05    Argentina

# %%
mydata.describe()
# Out:
#          Population      Rulal      Urban      Share     Growth
# count  3.500000e+01  35.000000  35.000000  35.000000  35.000000
# mean   3.459586e+07  61.160571  38.839429   2.857714  19.299143
# std    4.445234e+07  22.219493  22.219493   3.671310  11.125100
# min    6.447300e+04   2.500000  10.030000   0.010000  -0.580000
# 25%    1.421136e+06  52.790000  24.460000   0.115000  13.865000
# 50%    1.678794e+07  68.130000  31.870000   1.390000  18.810000
# 75%    6.076749e+07  75.540000  47.210000   5.020000  23.045000
# max    1.998123e+08  89.970000  97.500000  16.500000  55.880000

# %%
mydata.describe().T
# Out:
#             count          mean           std       min          25%  \
# Population   35.0  3.459586e+07  4.445234e+07  64473.00  1421136.000
# Rulal        35.0  6.116057e+01  2.221949e+01      2.50       52.790
# Urban        35.0  3.883943e+01  2.221949e+01     10.03       24.460
# Share        35.0  2.857714e+00  3.671310e+00      0.01        0.115
# Growth       35.0  1.929914e+01  1.112510e+01     -0.58       13.865
#
#                     50%           75%           max
# Population  16787941.00  6.076749e+07  1.998123e+08
# Rulal             68.13  7.554000e+01  8.997000e+01
# Urban             31.87  4.721000e+01  9.750000e+01
# Share              1.39  5.020000e+00  1.650000e+01
# Growth            18.81  2.304500e+01  5.588000e+01

# %%
mydata.shape
# Out:
# (35, 8)

# %%
mydata.describe(include=np.number,percentiles=[0.01,0.02,0.10]).T
# Out:
#             count          mean           std       min           1%  \
# Population   35.0  3.459586e+07  4.445234e+07  64473.00  125256.1600
# Rulal        35.0  6.116057e+01  2.221949e+01      2.50       2.5850
# Urban        35.0  3.883943e+01  2.221949e+01     10.03      10.4584
# Share        35.0  2.857714e+00  3.671310e+00      0.01       0.0134
# Growth       35.0  1.929914e+01  1.112510e+01     -0.58       1.2866
#
#                      2%         10%          50%           max
# Population  186039.3200  472579.400  16787941.00  1.998123e+08
# Rulal            2.6700      27.566        68.13  8.997000e+01
# Urban           10.8868      18.042        31.87  9.750000e+01
# Share            0.0168       0.038         1.39  1.650000e+01
# Growth           3.1532       7.408        18.81  5.588000e+01
